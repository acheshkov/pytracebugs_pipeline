# %% [markdown]
# # **Test `Representation Creator`**

# %% [markdown]
# ## Environment

# %%
# !python --version

# %% [markdown]
# ## Dependencies

# %%
from google.colab import files
files.upload()

# %%
# !pip install tokenizers
# !pip install transformers

# %%
from code_representation import CodeRepresentation

# %% [markdown]
# ## Settings

# %% [markdown]
# # Run

# %%
cr = CodeRepresentation(install=True, download=True, device_id='cuda:0')
#cr = CodeRepresentation(install=True, download=True, device_id='cpu')

# %%
# %time cr.run(limit=100)
