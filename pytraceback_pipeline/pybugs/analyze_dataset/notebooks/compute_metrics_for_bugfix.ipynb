# %%
import pandas as pd
import numpy as np
from radon.visitors import ComplexityVisitor
from radon.complexity import cc_rank
from radon.metrics import h_visit, mi_visit
from radon.raw import analyze

# %% [markdown]
# # Загрузка данных багфиксов

# %%
path_to_data = '/home/kks/zephyr_data/buggy_code/'
source_code_data = pd.read_pickle(path_to_data + 'bugfixes_test.pickle')

# %%
import re

def removeExtraSpaces(snippet):
    number_of_spaces_to_remove = re.search('\S', snippet.split('\n')[0]).start(0)
    return '\n'.join([snippet_line[number_of_spaces_to_remove:] 
                      for snippet_line in snippet.split('\n')])


def refineSnippet(snippet):
    try:
        ComplexityVisitor.from_code(snippet)
        return snippet
    except:
        try:
            snippet_with_removed_extra_spaces = removeExtraSpaces(snippet)
            ComplexityVisitor.from_code(snippet_with_removed_extra_spaces)
            return snippet_with_removed_extra_spaces
        except:
            return np.nan

# %%
source_code_data['before_merge'] = source_code_data['before_merge'].apply(refineSnippet)
source_code_data['after_merge'] = source_code_data['after_merge'].apply(refineSnippet)

# %%
source_code_data = source_code_data.loc[source_code_data['before_merge'].notna()]
source_code_data = source_code_data.loc[source_code_data['after_merge'].notna()]

# %% [markdown]
# # Функции вычисления метрик

# %%
def computeCyclomaticComplexity(snippet):
    return ComplexityVisitor.from_code(snippet).functions_complexity


def isFunction(snippet):
    return not ComplexityVisitor.from_code(snippet).functions[0].is_method


def computeHastadMetrics(snippet):
    hastad_metrics = h_visit(snippet).total
    return {metric:getattr(hastad_metrics, metric) for metric in dir(hastad_metrics) 
            if (not metric.startswith('_')) and ('index' not in metric) and ('count' not in metric)}


def computeRawMetrics(snippet):
    raw_metrics = analyze(snippet)
    return {metric:getattr(raw_metrics, metric) for metric in dir(raw_metrics) 
            if (not metric.startswith('_')) and ('index' not in metric) and ('count' not in metric)}


def computeMIindex(snippet):
    return mi_visit(snippet, multi=False)

# %% [markdown]
# # Цикломатическая сложность

# %%
source_code_data['cc_before'] = source_code_data['before_merge'].apply(computeCyclomaticComplexity)
source_code_data['cc_after'] = source_code_data['after_merge'].apply(computeCyclomaticComplexity)
source_code_data['is function_before'] = source_code_data['before_merge'].apply(isFunction)
source_code_data['is function_after'] = source_code_data['after_merge'].apply(isFunction)
source_code_data['cc_rank_before'] = source_code_data['cc_before'].apply(cc_rank)
source_code_data['cc_rank_after'] = source_code_data['cc_before'].apply(cc_rank)

# %% [markdown]
# # Метрики Хастада

# %%
hastad_metrics_before = source_code_data['before_merge'].apply(computeHastadMetrics)
hastad_metrics_after = source_code_data['after_merge'].apply(computeHastadMetrics)

# %%
for col in hastad_metrics_before.iloc[-1].keys():
    source_code_data[col + '_before'] = hastad_metrics_before.apply(lambda x: x[col])
    source_code_data[col + '_after'] = hastad_metrics_after.apply(lambda x: x[col])

# %% [markdown]
# # Сырые метрики

# %%
raw_metrics_before = source_code_data['before_merge'].apply(computeRawMetrics)
raw_metrics_after = source_code_data['after_merge'].apply(computeRawMetrics)

# %%
for col in raw_metrics_before.iloc[-1].keys():
    source_code_data[col + '_before'] = raw_metrics_before.apply(lambda x: x[col])
    source_code_data[col + '_after'] = raw_metrics_after.apply(lambda x: x[col])

# %% [markdown]
# # Индекс

# %%
source_code_data['MI_before'] = source_code_data['before_merge'].apply(computeMIindex)
source_code_data['MI_after'] = source_code_data['after_merge'].apply(computeMIindex)

# %%
source_code_data.to_pickle(path_to_data + 'bugfixes_test_metrics.pickle')

# %%
source_code_data
# Out:
#                                              before_merge  \
# 353547  def remove_lb_backend_address_pool_address(cmd...
# 355403  def split_action(arguments):\n    class SplitA...
# 379188  def parse_series(self, data, **kwargs):\n    l...
# 99259   def __init__(self, **kwargs):\n    # Save valu...
# 403629  def dump_checkpoint(self, weights_only: bool =...
# ...                                                   ...
# 19489   def process(self):\n    """\n    The Ransomwar...
# 19586   @staticmethod\ndef sanitize(value):\n    value...
# 20894   def __init__(self, execer, ctx, **kwargs):\n  ...
# 20902   def cd(args, stdin=None):\n    """Changes the ...
# 20957   def find_spec(self, fullname, path, target=Non...
#
#                                               after_merge  \
# 353547  def remove_lb_backend_address_pool_address(cmd...
# 355403  def split_action(arguments):\n    class SplitA...
# 379188  def parse_series(self, data, **kwargs):\n    l...
# 99259   def __init__(self, **kwargs):\n    # Save valu...
# 403629  def dump_checkpoint(self, weights_only: bool =...
# ...                                                   ...
# 19489   def process(self):\n    """\n    The Ransomwar...
# 19586   @staticmethod\ndef sanitize(value):\n    value...
# 20894   def __init__(self, execer, ctx, **kwargs):\n  ...
# 20902   def cd(args, stdin=None):\n    """Changes the ...
# 20957   def find_spec(self, fullname, path, target=Non...
#
#                                                       url  \
# 353547    https://github.com/Azure/azure-cli/issues/14342
# 355403      https://github.com/Azure/azure-cli/issues/793
# 379188     https://github.com/Flexget/Flexget/issues/2276
# 99259   https://github.com/GenericMappingTools/pygmt/i...
# 403629  https://github.com/PyTorchLightning/pytorch-li...
# ...                                                   ...
# 19489     https://github.com/certtools/intelmq/issues/967
# 19586    https://github.com/certtools/intelmq/issues/1022
# 20894          https://github.com/xonsh/xonsh/issues/1070
# 20902          https://github.com/xonsh/xonsh/issues/1667
# 20957          https://github.com/xonsh/xonsh/issues/1533
#
#                                                  bug type  \
# 353547                        CWE-248: Uncaught Exception
# 355403  CWE-754: Improper Check for Unusual or Excepti...
# 379188  CWE-754: Improper Check for Unusual or Excepti...
# 99259   CWE-754: Improper Check for Unusual or Excepti...
# 403629  CWE-754: Improper Check for Unusual or Excepti...
# ...                                                   ...
# 19489   CWE-167: Improper Handling of Additional Speci...
# 19586   CWE-237: Improper Handling of Structural Eleme...
# 20894      CWE-232: Improper Handling of Undefined Values
# 20902   CWE-126: Buffer Over-read, CWE-248: Uncaught E...
# 20957   CWE-274: Improper Handling of Insufficient Pri...
#
#                                           bug description  \
# 353547  Uncaught Exception when adding an address to a...
# 355403  Attribute `arg.name` of `namespace` can be a s...
# 379188  `guess_result.get('title')` can return None, t...
# 99259   There can be no value for key in default. No c...
# 403629                There is no check if scaler is None
# ...                                                   ...
# 19489   when processing a variable io.StringIO(raw_rep...
# 19586   when calling sanitize from self.__sanitize_val...
# 20894   when working with the xonsh shell, a PromptToo...
# 20902   the xonsh emulates command line and Python in ...
# 20957   the case is unhandled where a directory marked...
#
#                                              bug filename  \
# 353547  src/azure-cli/azure/cli/command_modules/networ...
# 355403  src/azure-cli-core/azure/cli/core/commands/arm.py
# 379188          flexget/plugins/parsers/parser_guessit.py
# 99259                                    pygmt/modules.py
# 403629           pytorch_lightning/trainer/training_io.py
# ...                                                   ...
# 19489   intelmq/bots/parsers/abusech/parser_ransomware.py
# 19586                        intelmq/lib/harmonization.py
# 20894                                 xonsh/base_shell.py
# 20902                                   xonsh/dirstack.py
# 20957                                   xonsh/imphooks.py
#
#                                 bug function_name bug lines  \
# 353547     remove_lb_backend_address_pool_address       [5]
# 355403             add_id_parameters.split_action      [16]
# 379188                 ParserGuessit.parse_series       NaN
# 99259                             config.__init__       [6]
# 403629             TrainerIOMixin.dump_checkpoint      [46]
# ...                                           ...       ...
# 19489   AbuseCHRansomwaretrackerParserBot.process      [11]
# 19586                               FQDN.sanitize       [3]
# 20894                          BaseShell.__init__    [5, 6]
# 20902                                          cd  [45, 46]
# 20957                   XonshImportHook.find_spec      [13]
#
#                                            full_traceback  \
# 353547  john@Azure:~$ az network lb address-pool addre...
# 355403  'str' object has no attribute 'append'\nTraceb...
# 379188  2018-12-10 19:39 DEBUG    parser_guessit movin...
# 99259   pygmt-session [ERROR]: Syntax error: Unrecogni...
# 403629  Running command:\npython pipe/train_cnn.py\n/h...
# ...                                                   ...
# 19489   Traceback (most recent call last):\nFile "<std...
# 19586   'source_queue': 'shadowserver-parser-dns-open-...
# 20894   cryzed@arch ~ $ xonsh update-aur-gits.xsh\nTra...
# 20902   Traceback (most recent call last):\nFile "C:\U...
# 20957   (C:\Anaconda3) C:\Users\kpr>xonsh\nTraceback (...
#
#                        traceback_type  ... loc_before loc_after  multi_before  \
# 353547                 AttributeError  ...          7         9             0
# 355403                 AttributeError  ...         23        30             5
# 379188                 AttributeError  ...        154       156             0
# 99259   pygmt.exceptions.GMTCLibError  ...         13        40             0
# 403629                 AttributeError  ...         68        68             6
# ...                               ...  ...        ...       ...           ...
# 19489                      _csv.Error  ...         44        45             5
# 19586                    UnicodeError  ...          5         5             0
# 20894                  AttributeError  ...         14        13             0
# 20902                      IndexError  ...         56        56             4
# 20957                 PermissionError  ...         20        20             0
#
#         multi_after  single_comments_before  single_comments_after  \
# 353547            0                       0                      0
# 355403            5                       0                      0
# 379188            0                      12                     12
# 99259             0                       2                      2
# 403629            6                      11                     11
# ...             ...                     ...                    ...
# 19489             5                       0                      0
# 19586             0                       0                      0
# 20894             0                       0                      0
# 20902             4                       1                      1
# 20957             0                       1                      1
#
#        sloc_before sloc_after   MI_before    MI_after
# 353547           7          9   77.880583   71.425380
# 355403          15         22   83.765366   83.845833
# 379188         136        138   40.457703   40.026548
# 99259           10         37  100.000000   83.132187
# 403629          37         37   76.393348   75.571340
# ...            ...        ...         ...         ...
# 19489           35         36   47.541555   47.000054
# 19586            5          5  100.000000  100.000000
# 20894           14         13  100.000000  100.000000
# 20902           48         48   50.684319   50.342384
# 20957           19         19   55.935402   55.104587
#
# [161 rows x 58 columns]
